# %% [markdown]
# # Pre-Experiment
# Define All Variables to Run the Experiment
#     <p>```setup.bash``` Exports the Variables to a ```setup.conf``` and sends it to the server</p>

# %%
username=sgt43 # Username of user on server
exp_name=dsef-janus # Name of Experiment on TestBed
proj_name=cops # Name of Project on TestBed
default_node=node-0 # Default node to run the experiment from
ds=cops2
host_ip=users.emulab.net
host_servers_ip=emulab.net
default_ip=${default_node}.${exp_name}.${proj_name}.${host_servers_ip}
proj_path=/home/sgt43/DSEF

# Setup Number of Servers and Clients
nservers=2 # Number of Servers and Clients
ndcs=2 # Number of Data Centers
eindex=0
ipprefix="node-"
ippostfix=""
threads=1
replication_factor=$ndcs

# Initialize Consistent Variables
trial=1 # Number of Trials in the Experiment
nkeys=10000 # Number of keys for the Experiment
run_time=10 # Time to run the Expierment
trim=1 # Trimmed time from the gathered results

# Initialize Default Variables
value_size=128 # Size of the Value Read and/or Written
cols_per_key_read=5 # Columns per key read
cols_per_key_write=5 # Columns per key write
keys_per_read=5 # Keys per read
keys_per_write=5 # Keys per write
write_frac="0.1" # Fraction of Write Operations to Read Operations
write_trans_frac="0.5" # Fraction of Write Transcation to Read Transactions

# Specify the Experiment's Indepdent Variable and its Values
exp=keys_per_read # Name of the Experiment
indep_values="1:${nkeys} 2:${nkeys}" # Independent Variables to be Experimented with

insert_cmd=INSERTCL
KILLALL_SSH_TIME=90
MAX_ATTEMPTS=10

alias emulab="ssh ${username}@${host_ip} -o StrictHostKeyChecking=no"
alias server="ssh ${username}@${host_ip} -o StrictHostKeyChecking=no ssh ${default_ip} -t -t -o StrictHostKeyChecking=no"

source ${proj_path}/setup.bash
# Out:
# setup.conf
#             432 100%    0.00kB/s    0:00:00 (xfr#1, to-chk=0/1)
# dynamic_common.bash
#           7,261 100%    6.26MB/s    0:00:00 (xfr#1, to-chk=0/1)
# kodiak_dc_launcher.bash
#           4,854 100%    3.96MB/s    0:00:00 (xfr#1, to-chk=0/1)

# %% [markdown]
# # Experiment
# Launch Instances of the Distributed System
#
# Setup Benchmark on Clients
#
# Start the Experiment
#
# Kill all Instances of the Distributed System

# %%
emulab "/usr/testbed/bin/node_reboot -w -e ${proj_name},${exp_name}"

server <<- 'EOF'

source dynamic_common.bash

nserverstotal=$((ndcs*nservers))

init

for t in $(seq $trial); do
for i in $(seq 0 $((${#var[@]} - 1))); do

    kill_all_ds
        
    setup

    launch
    
    set_server_keyspace
    
    set_client_keyspace
        
    for (( j = 1; j<=$((nserverstotal)); j++)); do
        ssh -o StrictHostKeyChecking=no node-${j} "collectl -P -ou -R $((run_time+20))s -f/tmp/${ds}_${t}" &
    done
    
    run_experiment
    
    kill_all_ds
    
    gather_results
    
    for (( j = 1; j<=$((nserverstotal)); j++)); do
        rsync --remove-source-files -az node-${j}:/tmp/${ds}* ${output_dir}
    done
    
done; done; exit; exit;
EOF

rm -rf ${proj_path}/latest

rsync -az --copy-links ${username}@${host_ip}:/users/${username}/${ds}/experiments/dynamic_${exp}/latest ${proj_path}

cd ${proj_path}/latest
mkdir data
for i in $(ls *.gz); do
    mv ${i} ./data/
    gunzip ./data/${i}
done
# Out:
# source dynamic_common.bash
#
# nserverstotal=$((ndcs*nservers))
#
# init
#
# for t in $(seq $trial); do
# for i in $(seq 0 $((${#var[@]} - 1))); do
#
#     kill_all_ds
#
#     setup
#
#     launch
#
#     set_server_keyspace
#
#     set_client_keyspace
#
#     for (( j = 1; j<=$((nserverstotal)); j++)); do
#         ssh -o StrictHostKeyChecking=no node-${j} "collectl -P -ou -R $((run_time+20))s -f/tmp/${ds}_${t}" &
#     done
#
#     run_experiment
#
#     kill_all_ds
#
#     gather_results
#
#     for (( j = 1; j<=$((nserverstotal)); j++)); do
#         rsync --remove-source-files -az node-${j}:/tmp/${ds}* ${output_dir}
#     done
#
# done; done; exit; exit;
# Welcome to Ubuntu 16.04.1 LTS (GNU/Linux 4.4.0-45-generic x86_64)
#
#  * Documentation:  https://help.ubuntu.com
#  * Management:     https://landscape.canonical.com
#  * Support:        https://ubuntu.com/advantage
# Last login: Wed May 31 15:29:03 2017 from 155.98.33.74
# sgt43@node-0:~$
# sgt43@node-0:~$ source dynamic_common.bash
# sgt43@node-0:~$
# sgt43@node-0:~$ nserverstotal=$((ndcs*nservers))
# sgt43@node-0:~$
# sgt43@node-0:~$ init
# rm: cannot remove '/users/sgt43/cops2/experiments/dynamic_keys_per_read/latest': Is a directory
# sgt43@node-0:~$
# sgt43@node-0:~$ for t in $(seq $trial); do
# > for i in $(seq 0 $((${#var[@]} - 1))); do
# >
# >     kill_all_ds
# >
# >     setup
# >
# >     launch
# >
# >     set_server_keyspace
# >
# >     set_client_keyspace
# >
# >     for (( j = 1; j<=$((nserverstotal)); j++)); do
# <collectl -P -ou -R $((run_time+20))s -f/tmp/${ds}_$                        {t}" &20))s -f/tmp/${ds}_
# >     done
# >
# >     run_experiment
# >
# >     kill_all_ds
# >
# >     gather_results
# >
# >     for (( j = 1; j<=$((nserverstotal)); j++)); do
# >         rsync --remove-source-files -az node-${j}:/tmp/${ds}* ${output_dir}
# >     done
# >
# > done; done; exit; exit;
# Connection to node-1 closed.
# Connection to node-2 closed.
# seeds=node-1, node-2
# node-1
# node-2
# node-1
# ssh -t -t -o StrictHostKeyChecking=no $ip "cops2/kill_all_cassandra.bash"
# Connection to node-2 closed.
# node-2
# ssh -t -t -o StrictHostKeyChecking=no $ip "cops2/kill_all_cassandra.bash"
# Connection to node-1 closed.
# node-2: Connection to node-2 closed.
# node-1: Connection to node-1 closed.
# 0 @ node-1
# 1 @ node-2
# node-2 is LAUNCHING!!!
# node-2: LAUNCHING SUCCESSFULLY!!!
# node-1 is LAUNCHING!!!
# node-1: LAUNCHING SUCCESSFULLY!!!
# Nodes up and normal:
# Number of normal nodes:  2
# [1] 8486
# Created keyspaces. Sleeping 5s for propagation.
# [1]+  Terminated              ( sleep 60; killall stress )
# [1] 8510
# Unable to create stress keyspace: Keyspace names must be case-insensitively unique ("Keyspace1" conflicts with "Keyspace1")
# [1]+  Terminated              ( sleep 60; killall stress )
# [1] 8534
# Unable to create stress keyspace: Keyspace names must be case-insensitively unique ("Keyspace1" conflicts with "Keyspace1")
# [1]+  Terminated              ( sleep 60; killall stress )
# [1] 8558
# Connection to node-3 closed.
# [2] 8571
# pop_pids:  8571
# node-3: /users/sgt43/cops2/kill_stress_kodiak.bash: line 6: kill: (10084) - No such process
# Connection to node-4 closed.
# [3] 8583
# pop_pids:  8571 8583
# Waiting on 8571
# node-4: /users/sgt43/cops2/kill_stress_kodiak.bash: line 6: kill: (10076) - No such process
# node-3: Unable to create stress keyspace: Keyspace names must be case-insensitively unique ("Keyspace1" conflicts with "Keyspace1")
# node-4: Unable to create stress keyspace: Keyspace names must be case-insensitively unique ("Keyspace1" conflicts with "Keyspace1")
# node-3: No Latencies percentiles to print
# node-4: No Latencies percentiles to print
# [2]-  Done                    ssh $client -o StrictHostKeyChecking=no "$stress_killer; 		     cd ${src_dir}/tools/stress; bin/stress --nodes=$first_dc_servers_csv 		     --columns=$cols_per_key_read --column-size=$value_size --operation=${insert_cmd} 		     --consistency-level=LOCAL_QUORUM --replication-strategy=NetworkTopologyStrategy 		     --strategy-properties=$strategy_properties --num-different-keys=$keys_per_client_first		     --num-keys=$keys_per_client_first --stress-index=$index 		     --stress-count=$num_nodes_per_dc 		     --file=${src_dir}/stress.out 		      > >(tee /local/${dynamic_dir}/${exp_uid}/populate${t}.out) 		     2> >(tee /local/${dynamic_dir}/${exp_uid}/populate${t}.err)" 2>&1 | awk '{ print "'$client': "$0 }'
# Waiting on 8583
# [3]+  Done                    ssh $client -o StrictHostKeyChecking=no "$stress_killer; 		     cd ${src_dir}/tools/stress; bin/stress --nodes=$first_dc_servers_csv 		     --columns=$cols_per_key_read --column-size=$value_size --operation=${insert_cmd} 		     --consistency-level=LOCAL_QUORUM --replication-strategy=NetworkTopologyStrategy 		     --strategy-properties=$strategy_properties --num-different-keys=$keys_per_client_first		     --num-keys=$keys_per_client_first --stress-index=$index 		     --stress-count=$num_nodes_per_dc 		     --file=${src_dir}/stress.out 		      > >(tee /local/${dynamic_dir}/${exp_uid}/populate${t}.out) 		     2> >(tee /local/${dynamic_dir}/${exp_uid}/populate${t}.err)" 2>&1 | awk '{ print "'$client': "$0 }'
# KILLEDKILLALL
# [2] 8584
# [3] 8585
# [4] 8586
# [5] 8587
# Connection to node-3 closed.
# [1]   Killed                  ( sleep $KILLALL_SSH_TIME; killall ssh )
# [6] 8599
# Connection to node-4 closed.
# [7] 8611
# node-3: total,interval_op_rate,interval_key_rate,avg_latency,elapsed_time
# node-4: total,interval_op_rate,interval_key_rate,avg_latency,elapsed_time
# node-3: 0,0,0,0,0,NaN,1
# node-4: 0,0,0,0,0,NaN,1
# node-3: 19,19,23,115,14720,0.0518421052631579,2
# node-4: 61,61,81,405,51240,0.016327868852459015,2
# node-3: 62,43,75,375,48000,0.024627906976744187,3
# node-4: 222,161,193,965,121720,0.0060248447204968945,3
# node-3: 129,67,99,495,63360,0.01544776119402985,4
# node-4: 464,242,330,1650,210600,0.0037355371900826446,4
# node-3: 183,54,82,410,51280,0.019222222222222224,5
# node-4: 685,221,341,1705,217040,0.004063348416289593,5
# node-3: 238,55,75,375,47400,0.01890909090909091,6
# node-4: 876,191,283,1415,179920,0.004827225130890052,6
# node-3: 298,60,88,440,53920,0.0174,7
# node-4: 1080,204,296,1480,187640,0.0045294117647058825,7
# node-3: 366,68,100,500,60400,0.015602941176470589,8
# node-4: 1281,201,273,1365,172920,0.0045572139303482586,8
# node-3: 424,58,82,410,51280,0.01796551724137931,9
# node-4: 1503,222,302,1510,189080,0.004193693693693694,9
# node-3: 478,54,86,430,52040,0.019462962962962963,11
# node-4: 1744,241,321,1605,202440,0.0037800829875518673,11
# node-3: 532,54,74,370,44960,0.01948148148148148,12
# node-4: 1994,250,362,1810,226880,0.003632,12
# node-3: 598,66,94,470,55360,0.01577272727272727,13
# node-4: 2265,271,359,1795,220160,0.0032878228782287824,13
# node-3: 658,60,80,400,45800,0.01755,14
# node-4: 2564,299,455,2275,279200,0.0028729096989966556,14
# node-3: 710,52,76,380,45040,0.020057692307692308,15
# node-4: 2878,314,466,2330,292840,0.002732484076433121,15
# node-3: 759,49,57,285,34080,0.02193877551020408,16
# node-4: 3197,319,435,2175,272400,0.002736677115987461,16
# node-3: 853,94,130,650,73600,0.010914893617021276,17
# node-4: 3595,398,530,2650,328400,0.0020678391959798995,17
# node-3: 962,109,145,725,81400,0.009302752293577982,18
# node-4: 3963,368,516,2580,317640,0.0022554347826086955,18
# node-3: /users/sgt43/cops2/kill_stress_kodiak.bash: line 6: kill: (10363) - No such process
# node-4: /users/sgt43/cops2/kill_stress_kodiak.bash: line 6: kill: (10353) - No such process
# [2]   Done                    ssh -o StrictHostKeyChecking=no node-${j} "collectl -P -ou -R $((run_time+20))s -f/tmp/${ds}_${t}"
# [3]   Done                    ssh -o StrictHostKeyChecking=no node-${j} "collectl -P -ou -R $((run_time+20))s -f/tmp/${ds}_${t}"
# [6]-  Done                    ssh $client -o StrictHostKeyChecking=no "cd ${src_dir}/tools/stress; 	    	((bin/stress --progress-interval=1 --nodes=$local_servers_csv --operation=DYNAMIC 	    	--consistency-level=LOCAL_QUORUM --replication-strategy=NetworkTopologyStrategy 	    	--strategy-properties=$strategy_properties --num-different-keys=$keys --stress-index=$index 	    	--stress-count=$num_nodes_per_dc --num-keys=20000000 --column-size=$value_size 	    	--columns-per-key-read=$cols_per_key_read --columns-per-key-write=$cols_per_key_write 	    	--keys-per-read=$keys_per_read --keys-per-write=$keys_per_write --write-fraction=$write_frac 	    	--write-transaction-fraction=$write_trans_frac --threads=$threads 	    	 > >(tee ${cli_output_dir}/${data_file_name}) 	    	2> ${cli_output_dir}/${data_file_name}.stderr) &); 	    	sleep $((run_time+10)); ${src_dir}/kill_stress_kodiak.bash" 2>&1 | awk '{ print "'$client': "$0 }'
# [7]+  Done                    ssh $client -o StrictHostKeyChecking=no "cd ${src_dir}/tools/stress; 	    	((bin/stress --progress-interval=1 --nodes=$local_servers_csv --operation=DYNAMIC 	    	--consistency-level=LOCAL_QUORUM --replication-strategy=NetworkTopologyStrategy 	    	--strategy-properties=$strategy_properties --num-different-keys=$keys --stress-index=$index 	    	--stress-count=$num_nodes_per_dc --num-keys=20000000 --column-size=$value_size 	    	--columns-per-key-read=$cols_per_key_read --columns-per-key-write=$cols_per_key_write 	    	--keys-per-read=$keys_per_read --keys-per-write=$keys_per_write --write-fraction=$write_frac 	    	--write-transaction-fraction=$write_trans_frac --threads=$threads 	    	 > >(tee ${cli_output_dir}/${data_file_name}) 	    	2> ${cli_output_dir}/${data_file_name}.stderr) &); 	    	sleep $((run_time+10)); ${src_dir}/kill_stress_kodiak.bash" 2>&1 | awk '{ print "'$client': "$0 }'
# [4]-  Done                    ssh -o StrictHostKeyChecking=no node-${j} "collectl -P -ou -R $((run_time+20))s -f/tmp/${ds}_${t}"
# Connection to node-1 closed.
# Connection to node-2 closed.
# Connection to node-1 closed.
# Connection to node-2 closed.
# seeds=node-1, node-2
# node-1
# node-2
# node-1
# ssh -t -t -o StrictHostKeyChecking=no $ip "cops2/kill_all_cassandra.bash"
# Connection to node-2 closed.
# node-2
# ssh -t -t -o StrictHostKeyChecking=no $ip "cops2/kill_all_cassandra.bash"
# Connection to node-1 closed.
# node-2: Connection to node-2 closed.
# node-1: Connection to node-1 closed.
# 0 @ node-1
# 1 @ node-2
# node-2 is LAUNCHING!!!
# node-2: LAUNCHING SUCCESSFULLY!!!
# node-1 is LAUNCHING!!!
# node-1: LAUNCHING SUCCESSFULLY!!!
# Nodes up and normal:
# Number of normal nodes:  2
# [1] 8764
# Created keyspaces. Sleeping 5s for propagation.
# [1]+  Terminated              ( sleep 60; killall stress )
# [1] 8788
# Unable to create stress keyspace: Keyspace names must be case-insensitively unique ("Keyspace1" conflicts with "Keyspace1")
# [1]+  Terminated              ( sleep 60; killall stress )
# [1] 8812
# Unable to create stress keyspace: Keyspace names must be case-insensitively unique ("Keyspace1" conflicts with "Keyspace1")
# [1]+  Terminated              ( sleep 60; killall stress )
# [1] 8836
# Connection to node-3 closed.
# [2] 8849
# pop_pids:  8849
# node-3: /users/sgt43/cops2/kill_stress_kodiak.bash: line 6: kill: (10506) - No such process
# Connection to node-4 closed.
# [3] 8861
# pop_pids:  8849 8861
# Waiting on 8849
# node-4: /users/sgt43/cops2/kill_stress_kodiak.bash: line 6: kill: (10496) - No such process
# node-3: Unable to create stress keyspace: Keyspace names must be case-insensitively unique ("Keyspace1" conflicts with "Keyspace1")
# node-4: Unable to create stress keyspace: Keyspace names must be case-insensitively unique ("Keyspace1" conflicts with "Keyspace1")
# node-3: No Latencies percentiles to print
# node-4: No Latencies percentiles to print
# [2]-  Done                    ssh $client -o StrictHostKeyChecking=no "$stress_killer; 		     cd ${src_dir}/tools/stress; bin/stress --nodes=$first_dc_servers_csv 		     --columns=$cols_per_key_read --column-size=$value_size --operation=${insert_cmd} 		     --consistency-level=LOCAL_QUORUM --replication-strategy=NetworkTopologyStrategy 		     --strategy-properties=$strategy_properties --num-different-keys=$keys_per_client_first		     --num-keys=$keys_per_client_first --stress-index=$index 		     --stress-count=$num_nodes_per_dc 		     --file=${src_dir}/stress.out 		      > >(tee /local/${dynamic_dir}/${exp_uid}/populate${t}.out) 		     2> >(tee /local/${dynamic_dir}/${exp_uid}/populate${t}.err)" 2>&1 | awk '{ print "'$client': "$0 }'
# Waiting on 8861
# [3]+  Done                    ssh $client -o StrictHostKeyChecking=no "$stress_killer; 		     cd ${src_dir}/tools/stress; bin/stress --nodes=$first_dc_servers_csv 		     --columns=$cols_per_key_read --column-size=$value_size --operation=${insert_cmd} 		     --consistency-level=LOCAL_QUORUM --replication-strategy=NetworkTopologyStrategy 		     --strategy-properties=$strategy_properties --num-different-keys=$keys_per_client_first		     --num-keys=$keys_per_client_first --stress-index=$index 		     --stress-count=$num_nodes_per_dc 		     --file=${src_dir}/stress.out 		      > >(tee /local/${dynamic_dir}/${exp_uid}/populate${t}.out) 		     2> >(tee /local/${dynamic_dir}/${exp_uid}/populate${t}.err)" 2>&1 | awk '{ print "'$client': "$0 }'
# KILLEDKILLALL
# [2] 8862
# [3] 8863
# [4] 8864
# [5] 8865
# Connection to node-3 closed.
# [1]   Killed                  ( sleep $KILLALL_SSH_TIME; killall ssh )
# [6] 8877
# Connection to node-4 closed.
# [7] 8889
# node-3: total,interval_op_rate,interval_key_rate,avg_latency,elapsed_time
# node-4: total,interval_op_rate,interval_key_rate,avg_latency,elapsed_time
# node-3: 0,0,0,0,0,NaN,1
# node-4: 0,0,0,0,0,NaN,1
# node-3: 6,6,12,60,7680,0.113,2
# node-4: 42,42,90,450,57600,0.022333333333333334,2
# node-3: 6,0,0,0,0,NaN,3
# node-4: 176,134,289,1445,184960,0.00726865671641791,3
# node-3: 6,0,0,0,0,NaN,4
# node-4: 332,156,360,1800,230400,0.0060448717948717945,4
# node-3: 35,29,79,395,50560,0.12120689655172413,5
# node-4: 510,178,410,2050,261800,0.005162921348314606,5
# node-3: 70,35,85,425,52600,0.03377142857142857,6
# node-4: 698,188,412,2060,262480,0.004824468085106383,6
# node-3: 127,57,129,645,81960,0.018333333333333333,7
# node-4: 860,162,372,1860,235080,0.005691358024691358,7
# node-3: 199,72,159,795,98160,0.014291666666666666,8
# node-4: 1044,184,425,2125,267200,0.005108695652173913,8
# node-3: 288,89,202,1010,124480,0.011370786516853932,9
# node-4: 1229,185,418,2090,263920,0.0050702702702702706,9
# node-3: 364,76,176,880,108440,0.013381578947368421,11
# node-4: 1432,203,469,2345,295960,0.004640394088669951,11
# node-3: 411,47,118,590,71920,0.022042553191489362,12
# node-4: 1654,222,501,2505,314040,0.004135135135135135,12
# node-3: 467,56,127,635,75280,0.018696428571428572,13
# node-4: 1878,224,505,2525,314200,0.004071428571428571,13
# node-3: 514,47,103,515,58720,0.022808510638297873,14
# node-4: 2164,286,674,3370,421760,0.003129370629370629,14
# node-3: 560,46,107,535,64280,0.022391304347826088,15
# node-4: 2470,306,681,3405,426840,0.002852941176470588,15
# node-3: 596,36,90,450,54000,0.03,16
# node-4: 2831,361,839,4195,526760,0.00225207756232687,16
# node-3: 618,22,44,220,23360,0.048045454545454544,17
# node-4: 3223,392,919,4595,576760,0.0020331632653061223,17
# node-3: 631,13,29,145,15560,0.08492307692307692,18
# node-4: 3535,312,729,3645,456960,0.0027243589743589742,18
# node-3: /users/sgt43/cops2/kill_stress_kodiak.bash: line 6: kill: (10782) - No such process
# node-4: /users/sgt43/cops2/kill_stress_kodiak.bash: line 6: kill: (10772) - No such process
# [2]   Done                    ssh -o StrictHostKeyChecking=no node-${j} "collectl -P -ou -R $((run_time+20))s -f/tmp/${ds}_${t}"
# [3]   Done                    ssh -o StrictHostKeyChecking=no node-${j} "collectl -P -ou -R $((run_time+20))s -f/tmp/${ds}_${t}"
# [4]   Done                    ssh -o StrictHostKeyChecking=no node-${j} "collectl -P -ou -R $((run_time+20))s -f/tmp/${ds}_${t}"
# [5]   Done                    ssh -o StrictHostKeyChecking=no node-${j} "collectl -P -ou -R $((run_time+20))s -f/tmp/${ds}_${t}"
# [6]-  Done                    ssh $client -o StrictHostKeyChecking=no "cd ${src_dir}/tools/stress; 	    	((bin/stress --progress-interval=1 --nodes=$local_servers_csv --operation=DYNAMIC 	    	--consistency-level=LOCAL_QUORUM --replication-strategy=NetworkTopologyStrategy 	    	--strategy-properties=$strategy_properties --num-different-keys=$keys --stress-index=$index 	    	--stress-count=$num_nodes_per_dc --num-keys=20000000 --column-size=$value_size 	    	--columns-per-key-read=$cols_per_key_read --columns-per-key-write=$cols_per_key_write 	    	--keys-per-read=$keys_per_read --keys-per-write=$keys_per_write --write-fraction=$write_frac 	    	--write-transaction-fraction=$write_trans_frac --threads=$threads 	    	 > >(tee ${cli_output_dir}/${data_file_name}) 	    	2> ${cli_output_dir}/${data_file_name}.stderr) &); 	    	sleep $((run_time+10)); ${src_dir}/kill_stress_kodiak.bash" 2>&1 | awk '{ print "'$client': "$0 }'
# [7]+  Done                    ssh $client -o StrictHostKeyChecking=no "cd ${src_dir}/tools/stress; 	    	((bin/stress --progress-interval=1 --nodes=$local_servers_csv --operation=DYNAMIC 	    	--consistency-level=LOCAL_QUORUM --replication-strategy=NetworkTopologyStrategy 	    	--strategy-properties=$strategy_properties --num-different-keys=$keys --stress-index=$index 	    	--stress-count=$num_nodes_per_dc --num-keys=20000000 --column-size=$value_size 	    	--columns-per-key-read=$cols_per_key_read --columns-per-key-write=$cols_per_key_write 	    	--keys-per-read=$keys_per_read --keys-per-write=$keys_per_write --write-fraction=$write_frac 	    	--write-transaction-fraction=$write_trans_frac --threads=$threads 	    	 > >(tee ${cli_output_dir}/${data_file_name}) 	    	2> ${cli_output_dir}/${data_file_name}.stderr) &); 	    	sleep $((run_time+10)); ${src_dir}/kill_stress_kodiak.bash" 2>&1 | awk '{ print "'$client': "$0 }'
# Connection to node-1 closed.
# Connection to node-2 closed.
# logout
# Connection to node-0.dsef-janus.cops.emulab.net closed.
# ls: cannot access *.gz: No such file or directory

# %% [markdown]
# # Data Gathering and Post Processing
# Gather Data from Servers and Clients
#
# Post Process the Data into Meaningful Chunks
#
# Generate Graphs from the Data Chuncks

# %%
output_dir=${proj_path}/latest

source ${proj_path}/setup.conf
export ds

cd ${proj_path}/postprocess
./dynamic_postprocess_full.bash ${output_dir} ${output_dir} ${run_time} ${trim} shuffle
# Out:
# ls: cannot access /home/sgt43/DSEF/latest/client*: No such file or directory
# done shuffling
# tar: client*: Cannot stat: No such file or directory
# tar: Exiting with failure status due to previous errors
# rm: cannot remove '.trash': No such file or directory
# mv: cannot stat 'client*': No such file or directory
# ls: cannot access /home/sgt43/DSEF/latest/trial*: No such file or directory
# ls: cannot access /home/sgt43/DSEF/latest/trial*/cops2/*.sum.ops: No such file or directory
# /home/sgt43/DSEF/latest/cops2.graph
# ls: cannot access /home/sgt43/DSEF/latest/trial1/*/client0/*+tput: No such file or directory

# %% [markdown]
# # Graphing with GNUPlot

# %%
cd ${proj_path}/latest

source ${proj_path}/setup.conf
export ds

gnuplot <<- 'EOF'

    ds=system("echo ${ds}")
    
    set term png

    set output "bytes.png"
    plot ds.".graph" using 1:5 with linespoint title 'Bytes'

    set output "cols.png"
    plot ds.".graph" using 1:4 with linespoint title 'Cols'

    set output "keys.png"
    plot ds.".graph" using 1:3 with linespoint title 'Keys'

    set output "ops.png"
    plot ds.".graph" using 1:2 with linespoint title 'Ops'

EOF

display < bytes.png
display < cols.png
display < keys.png
display < ops.png

rm *.png
# Out:
#          line 0: warning: Skipping data file with no valid points
#
# gnuplot> plot ds.".graph" using 1:5 with linespoint title 'Bytes'
#                                                                  ^
#          line 0: x range is invalid
#
#          line 0: warning: Skipping data file with no valid points
#
# gnuplot> plot ds.".graph" using 1:4 with linespoint title 'Cols'
#                                                                 ^
#          line 0: x range is invalid
#
#          line 0: warning: Skipping data file with no valid points
#
# gnuplot> plot ds.".graph" using 1:3 with linespoint title 'Keys'
#                                                                 ^
#          line 0: x range is invalid
#
#          line 0: warning: Skipping data file with no valid points
#
# gnuplot> plot ds.".graph" using 1:2 with linespoint title 'Ops'
#                                                                ^
#          line 0: x range is invalid
#
# Not a valid image: b''Not a valid image: b''Not a valid image: b''Not a valid image: b''
